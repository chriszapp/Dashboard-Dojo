# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisaPolicarpo/Dashboard-Dojo_luisa/blob/main/project3_geral.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
import numpy as np
#import sqlalchemy as sql
import datetime

from PIL import Image 

import pickle

# %%
col_list = ['tconst','primaryTitle','originalTitle', 'startYear','genres','titleType']
title_basics = pd.read_csv('https://datasets.imdbws.com/title.basics.tsv.gz', compression = 'gzip', sep = '\t', usecols=col_list)

# %%
col_list2 = ['tconst','averageRating','numVotes']
title_ratings = pd.read_csv('https://datasets.imdbws.com/title.ratings.tsv.gz', compression = 'gzip', sep = '\t', usecols=col_list2)

# %%
col_list3 = ['nconst','primaryName','primaryProfession']
name_basics = pd.read_csv('https://datasets.imdbws.com/name.basics.tsv.gz', compression = 'gzip', sep = '\t', usecols=col_list3)

# %%
col_list4 = ['tconst','nconst']
title_principals = pd.read_csv('https://datasets.imdbws.com/title.principals.tsv.gz', compression = 'gzip', sep = '\t', usecols=col_list4)

# %%
t_b_r = pd.merge(title_basics, title_ratings, how='inner', on=['tconst', 'tconst'])

# %%
t_b_r.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   startYear                    genres  averageRating  numVotes
# 0      1894         Documentary,Short            5.7      1922
# 1      1892           Animation,Short            5.8       259
# 2      1892  Animation,Comedy,Romance            6.5      1733
# 3      1892           Animation,Short            5.6       174
# 4      1893              Comedy,Short            6.2      2544

# %%
condition = t_b_r['titleType'] == 'movie'
condition2 = t_b_r['titleType'] == 'short'
condition7 = t_b_r['startYear'] <= '2022'
m_s = t_b_r[condition | condition2 & condition7 ][['tconst','primaryTitle','originalTitle', 'startYear','genres','averageRating','numVotes','titleType']]

# %%
m_s.to_pickle('/content/tmg.pickle')

# %%
j_c = pd.read_pickle("/content/tmg.pickle")

# %%
j_c.head(9)
# Out:
#       tconst                                 primaryTitle  \
# 0  tt0000001                                   Carmencita
# 1  tt0000002                       Le clown et ses chiens
# 2  tt0000003                               Pauvre Pierrot
# 3  tt0000004                                  Un bon bock
# 4  tt0000005                             Blacksmith Scene
# 5  tt0000006                            Chinese Opium Den
# 6  tt0000007  Corbett and Courtney Before the Kinetograph
# 7  tt0000008       Edison Kinetoscopic Record of a Sneeze
# 8  tt0000009                                   Miss Jerry
#
#                                  originalTitle startYear  \
# 0                                   Carmencita      1894
# 1                       Le clown et ses chiens      1892
# 2                               Pauvre Pierrot      1892
# 3                                  Un bon bock      1892
# 4                             Blacksmith Scene      1893
# ...

# %%
t_b_r2 = pd.merge(j_c, title_principals, how='inner', on=['tconst', 'tconst'])

# %%
t_b_r2.head(9)
# Out:
#       tconst            primaryTitle           originalTitle startYear  \
# 0  tt0000001              Carmencita              Carmencita      1894
# 1  tt0000001              Carmencita              Carmencita      1894
# 2  tt0000001              Carmencita              Carmencita      1894
# 3  tt0000002  Le clown et ses chiens  Le clown et ses chiens      1892
# 4  tt0000002  Le clown et ses chiens  Le clown et ses chiens      1892
# 5  tt0000003          Pauvre Pierrot          Pauvre Pierrot      1892
# 6  tt0000003          Pauvre Pierrot          Pauvre Pierrot      1892
# 7  tt0000003          Pauvre Pierrot          Pauvre Pierrot      1892
# 8  tt0000003          Pauvre Pierrot          Pauvre Pierrot      1892
#
#                      genres  averageRating  numVotes titleType     nconst
# 0         Documentary,Short            5.7      1922     short  nm1588970
# 1         Documentary,Short            5.7      1922     short  nm0005690
# ...

# %%
t_b_r3 = pd.merge(t_b_r2, name_basics, how='inner', on=['nconst', 'nconst'])

# %%
t_b_r3.head()
# Out:
#       tconst                                 primaryTitle  \
# 0  tt0000001                                   Carmencita
# 1  tt0000001                                   Carmencita
# 2  tt0000005                             Blacksmith Scene
# 3  tt0000006                            Chinese Opium Den
# 4  tt0000007  Corbett and Courtney Before the Kinetograph
#
#                                  originalTitle startYear             genres  \
# 0                                   Carmencita      1894  Documentary,Short
# 1                                   Carmencita      1894  Documentary,Short
# 2                             Blacksmith Scene      1893       Comedy,Short
# 3                            Chinese Opium Den      1894              Short
# 4  Corbett and Courtney Before the Kinetograph      1894        Short,Sport
#
#    averageRating  numVotes titleType     nconst           primaryName  \
# 0            5.7      1922     short  nm1588970            Carmencita
# ...

# %%
t_b_r3.to_pickle('/content/tmg1.pickle')

# %%
movies = pd.read_pickle("/content/tmg1.pickle")

# %%
movies['titleType'].value_counts()
# Out:
# movie    2520964
# short     923320
# Name: titleType, dtype: int64

# %%
movies.drop(columns=['originalTitle', 'titleType','nconst'])
# Out:
#             tconst                                 primaryTitle startYear  \
# 0        tt0000001                                   Carmencita      1894
# 1        tt0000001                                   Carmencita      1894
# 2        tt0000005                             Blacksmith Scene      1893
# 3        tt0000006                            Chinese Opium Den      1894
# 4        tt0000007  Corbett and Courtney Before the Kinetograph      1894
# ...            ...                                          ...       ...
# 3444279  tt9916730                                       6 Gunn      2017
# 3444280  tt9916730                                       6 Gunn      2017
# 3444281  tt9916730                                       6 Gunn      2017
# 3444282  tt9916730                                       6 Gunn      2017
# 3444283  tt9916730                                       6 Gunn      2017
#
#                     genres  averageRating  numVotes           primaryName  \
# ...

# %%
movies.fillna(0, inplace = True)

# %%
movies["primaryProfession"] = movies.primaryProfession.str.split(',')
movies_split = movies.explode("primaryProfession")

# %%
movies_split['primaryProfession'].value_counts()
# Out:
# actor                        1213033
# writer                       1020033
# producer                      940642
# director                      872710
# actress                       590307
# soundtrack                    365505
# cinematographer               357978
# composer                      303393
# editor                        297184
# miscellaneous                 268143
# camera_department             268018
# music_department              231069
# assistant_director            123287
# editorial_department          115209
# production_manager             86394
# sound_department               82989
# art_department                 54976
# production_designer            49661
# script_department              33758
# animation_department           32705
# art_director                   32626
# visual_effects                 31727
# stunts                         26717
# executive                      18180
# casting_department             12709
# ...

# %%
condition = movies_split([['primaryProfession'] == 'actor') | (movies_split['primaryProfession'] =='writer') | (movies_split['primaryProfession'] =='producer') | (movies_split['primaryProfession'] == 'actress') | (movies_split['primaryProfession'] == 'director') | (movies_split['primaryProfession'] == 'soundtrack') | (movies_split['primaryProfession'] =='cinematographer')])

movies_adpw = movies_split[condition][['primaryName','tconst','genres','averageRating','numVotes','primaryProfession','titleType','startYear']]
# Out:
#   File "<ipython-input-21-59eeb9475617>", line 1
#     condition = movies_split([['primaryProfession'] == 'actor') | (movies_split['primaryProfession'] =='writer') | (movies_split['primaryProfession'] =='producer') | (movies_split['primaryProfession'] == 'actress') | (movies_split['primaryProfession'] == 'director') | (movies_split['primaryProfession'] == 'soundtrack') | (movies_split['primaryProfession'] =='cinematographer')])
#                                                               ^
# SyntaxError: invalid syntax

# %%
tconst	primaryTitle	startYear	genres	averageRating	numVotes	primaryName	primaryProfession

# %%
| (movies_split['primaryProfession'] == 'actress')
